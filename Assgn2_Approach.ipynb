# %% [markdown]
# <a href="https://colab.research.google.com/github/internship-bvoc2020/Assignment2-DataAnalysis/blob/master/Assgn2_Approach.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv("employee_data.csv",sep="\t")

# %%
df.head()
# Out:
#    age    employment_type  salary  ...    relationship   Gender hours_per_week
# 0   39          State-gov   77516  ...   Not-in-family     Male             40
# 1   50   Self-emp-not-inc   83311  ...         Husband     Male             13
# 2   38            Private  215646  ...   Not-in-family     Male             40
# 3   53            Private  234721  ...         Husband     Male             40
# 4   28            Private  338409  ...            Wife   Female             40
#
# [5 rows x 8 columns]

# %%
df.shape
# Out:
# (978, 8)

# %%
df.columns
# Out:
# Index(['age', 'employment_type', 'salary', 'education', 'marital-status',
#        'relationship', 'Gender', 'hours_per_week'],
#       dtype='object')

# %% [markdown]
# **Categorical & Continous Variables**

# %%
df.dtypes
# Out:
# age                 int64
# employment_type    object
# salary              int64
# education          object
# marital-status     object
# relationship       object
# Gender             object
# hours_per_week      int64
# dtype: object

# %%
num_cols = df._get_numeric_data().columns
num_cols
# Out:
# Index(['age', 'salary', 'hours_per_week'], dtype='object')

# %%
#Continous
for i in num_cols:
  print(str(i)+'\t'+str(len(df[i].unique())))
# Out:
# age	65
# salary	966
# hours_per_week	56

# %%
#Categorical
for j in list(set(df.columns) - set(num_cols)):
  print(str(j)+'\t'+str(len(df[j].unique())))
# Out:
# Gender	2
# employment_type	7
# marital-status	7
# relationship	6
# education	16

# %%
#Univariate Analysis
df.hist(figsize=[22,5],layout=(int(len(num_cols)/3),3))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f13b91dd080>,
# ...
#       dtype=object)

# %% [markdown]
# **Categorizing each Gender & Relationship status (combination of all values) , plot the hours_per_week worked.Choose appropriate plots.Mention the inferences drawn**

# %%
sns.set(style="ticks", color_codes=True)
fn =sns.FacetGrid(df,col='Gender',row='relationship',palette="GnBu_d",gridspec_kws={"width_ratios": [4, 4]}, height=2.5,aspect=4)
fn = fn.map(plt.hist,"hours_per_week")
for ax in fn.axes.flatten():
    ax.tick_params(labelbottom=True)

# %%
df.groupby(['Gender','relationship'])['hours_per_week'].sum().plot.pie(y='hours_per_week',figsize=[10,10])
